# %%
# Testing
import pandas as pd
import numpy as np

df = pd.Series([np.nan, "hi"])
list1 = [np.nan, 1]
pd.Series(list1)
list1.append(np.nan)
df = pd.DataFrame(list1)
df
# Out:
#      0
# 0  NaN
# 1  1.0
# 2  NaN

# %% [markdown]
# # Trial 1

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from time import sleep


def get_table_with_links():
    driver = webdriver.Chrome(r'chromedriver.exe')
    url = 'https://treaties.un.org/Pages/UNTSOnline.aspx?id=2'
    driver.get(url)
    search_box = driver.find_element_by_xpath('//*[@id="ctl00_ctl00_ContentPlaceHolder1_ContentPlaceHolderInnerPage_txtTitle"]')
    search_box.send_keys('tax')
    submit_search = driver.find_element_by_xpath('//*[@id="ctl00_ctl00_ContentPlaceHolder1_ContentPlaceHolderInnerPage_btnSubmit"]')
    submit_search.click()
    sleep(5)
    results_per_page = Select(driver.find_element_by_xpath('//*[@id="ctl00_ctl00_ContentPlaceHolder1_ContentPlaceHolderInnerPage_drpPageSize"]'))
    results_per_page.select_by_value('500')
    sleep(5)
    # Read first column
    # Yes I know I'm repeating myself here. I think this actually helps readability for beginner programmers.
   
    treaty_names = []
    for i in driver.find_elements_by_xpath('//*[@id="ctl00_ctl00_ContentPlaceHolder1_ContentPlaceHolderInnerPage_dgSearch"]/tbody/tr/td[2]'):
        try:
            name = i.get_attribute('title')
            treaty_names.append(name)
        except:
            treaty_names.append('')
    df = pd.DataFrame(index=treaty_names)
    # Read second column
    treaty_links = []
    for i in driver.find_elements_by_xpath('//*[@id="ctl00_ctl00_ContentPlaceHolder1_ContentPlaceHolderInnerPage_dgSearch"]/tbody/tr/td[3]/a'):
        try:
            link = i.get_attribute('href')
            treaty_links.append(link)
        except:
            treaty_links.append('')
    df['link'] = treaty_links
    
    # Read third column
    treaty_signed = []
    for i in driver.find_elements_by_xpath('//*[@id="ctl00_ctl00_ContentPlaceHolder1_ContentPlaceHolderInnerPage_dgSearch"]/tbody/tr/td[4]'):
        try:
            treaty_signed.append(i.text)
        except:
            treaty_signed.append('')
    df['signed'] = treaty_signed
    
    # Read fourth column
    treaty_entry = []
    for i in driver.find_elements_by_xpath('//*[@id="ctl00_ctl00_ContentPlaceHolder1_ContentPlaceHolderInnerPage_dgSearch"]/tbody/tr/td[5]'):
        try:
            treaty_entry.append(i.text)
        except:
            treaty_entry.append('')
    df['entry'] = treaty_entry
    driver.quit()
    df.to_csv('tax_table.csv')

get_table_with_links()
# Out:
# HIII: [<selenium.webdriver.remote.webelement.WebElement (session="b34ab9e19c45d9963f2ee08b81b4e2af", element="316262dd-3658-4f97-b8d0-5dd89d0f35d2")>, <selenium.webdriver.remote.webelement.WebElement (session="b34ab9e19c45d9963f2ee08b81b4e2af", element="7b6573cd-f008-455e-b7b8-5ce569668ee6")>, <selenium.webdriver.remote.webelement.WebElement (session="b34ab9e19c45d9963f2ee08b81b4e2af", element="d4596f7b-c6e4-40ab-98cb-7fadeb282d36")>, <selenium.webdriver.remote.webelement.WebElement (session="b34ab9e19c45d9963f2ee08b81b4e2af", element="bb68ad93-74dd-42ba-8b6b-9b773ce32dab")>, <selenium.webdriver.remote.webelement.WebElement (session="b34ab9e19c45d9963f2ee08b81b4e2af", element="14a72a2a-b1d9-47cc-904e-a4ff1f84da3d")>, <selenium.webdriver.remote.webelement.WebElement (session="b34ab9e19c45d9963f2ee08b81b4e2af", element="33129681-697e-4b76-981a-c304f91806b8")>, <selenium.webdriver.remote.webelement.WebElement (session="b34ab9e19c45d9963f2ee08b81b4e2af", element="becccf0f-ac3f-447f-bb70-
# ...

# %%
# !pip install selenium

# %% [markdown]
# # Trial 2

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from time import sleep
import numpy as np


def get_table_with_links():
    driver = webdriver.Chrome(r'chromedriver.exe')
    url = 'https://www.magicbricks.com/property-for-sale/residential-real-estate?proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment,Residential-House,Villa&cityName=Mumbai'
    driver.get(url)
    
    # Read first column
    # Yes I know I'm repeating myself here. I think this actually helps readability for beginner programmers.
    
    df = pd.DataFrame()
    treaty_date = []
    for i in driver.find_elements_by_xpath('//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div/table/tbody/tr/td[1]/span | //*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div/table/tbody/tr/td[1]'):
        try:
            if i.text != "-":
                treaty_date.append(i.text)
            else:
                treaty_date.append(np.nan)
        except:
            treaty_date.append(np.nan)
    df['date'] = pd.Series(treaty_date)
#    df = pd.DataFrame(index=treaty_date)
    
    treaty_open = []
    for i in driver.find_elements_by_xpath('//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div/table/tbody/tr/td[2]/span | //*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div/table/tbody/tr/td[2]'):
        try:
            if i.text != "-":
                treaty_open.append(i.text)
            else:
                treaty_open.append(np.nan)
        except:
            treaty_open.append(np.nan)
    df['open'] = pd.Series(treaty_open)
    
    treaty_high = []
    for i in driver.find_elements_by_xpath('//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div/table/tbody/tr/td[3]/span | //*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div/table/tbody/tr/td[3]'):
        try:
            if i.text != "-":
                treaty_high.append(i.text)
            else:
                treaty_high.append(np.nan)
        except:
            treaty_high.append(np.nan)
    df['high'] = pd.Series(treaty_high)
    
    treaty_low = []
    for i in driver.find_elements_by_xpath('//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div/table/tbody/tr/td[4]/span | //*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div/table/tbody/tr/td[4]'):
        try:
            if i.text != "-":
                treaty_low.append(i.text)
            else:
                treaty_low.append(np.nan)
        except:
            treaty_low.append(np.nan)
    df['low'] = pd.Series(treaty_low)
    
    treaty_close = []
    for i in driver.find_elements_by_xpath('//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div/table/tbody/tr/td[5]/span | //*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div/table/tbody/tr/td[5]'):
        try:
            if i.text != "-":
                treaty_close.append(i.text)
            else:
                treaty_close.append(np.nan)
        except:
            treaty_close.append(np.nan)
    df['close'] = pd.Series(treaty_close)
    
    treaty_volume = []
    for i in driver.find_elements_by_xpath('//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div/table/tbody/tr/td[7]/span | //*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div/table/tbody/tr/td[7]' ):
        try:
            if i.text != "-":
                treaty_volume.append(i.text)
            else:
                treaty_volume.append(np.nan)
        except:
            treaty_volume.append(np.nan)
    df['volume'] = pd.Series(treaty_volume)
    
    driver.quit()
    df.to_csv('stockfinal_table.csv', na_rep=np.nan)

get_table_with_links()

# %% [markdown]
# # Trial 3 - final

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from time import sleep
import numpy as np
from selenium.webdriver.common.keys import Keys 



def get_table_with_links():
    driver = webdriver.Chrome(r'C:\Users\Rohan\OneDrive\Desktop\chromedriver.exe')
    url = 'https://www.magicbricks.com/property-for-sale/residential-real-estate?proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment,Residential-House,Villa&cityName=Mumbai'
    driver.get(url)
    for i in range(20):
        driver.find_element_by_tag_name('body').send_keys(Keys.PAGE_DOWN)

    # Read first column
    # Yes I know I'm repeating myself here. I think this actually helps readability for beginner programmers.
    
    df = pd.DataFrame()
    
    treaty_date = []
    for i in driver.find_elements_by_xpath('//*[@id="resultBlockWrapper47259871"]/div/div/div/div/div/div[2]'):
        try:
            if i.text == "-":
                treaty_date.append(np.nan)
            else:
                child = i.find_element_by_xpath('./child::span')
                treaty_date.append(child.text)
        except:
            treaty_date.append(np.nan)
    df['date'] = pd.Series(treaty_date)
    
    treaty_volume = []
    for i in driver.find_elements_by_xpath('//*[@id="priceProperty47259871"]' ):
        try:
            if i.text == "-":
                treaty_volume.append(np.nan)
            else:
                child = i.find_element_by_xpath('./child::span')
                treaty_volume.append(child.text)
        except:
            treaty_volume.append(np.nan)
    df['volume'] = pd.Series(treaty_volume)
    
    driver.quit()
    df.to_csv('housing.csv', na_rep=np.nan)

get_table_with_links()
